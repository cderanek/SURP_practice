# %% [markdown]
# # NEON API exploration
#
# In this file, I'll be exploring the NEON API using [this NEON API tutorial](https://www.neonscience.org/resources/learning-hub/tutorials/neon-api-01-introduction-requests) and NEON AOP HDF5 reflectance files using [this NEON AOP HDF5 tutorial](https://www.neonscience.org/resources/learning-hub/tutorials/neon-aop-hdf5-tile-py)

# %%
import requests # necessary for NEON API
import json

import numpy as np # necessary for exploring h5 files
import h5py
import osgeo.gdal, osgeo.osr, os
import matplotlib.pyplot as plt

from collections import namedtuple # for nicely organizing the many URLs and metadata
from itertools import chain # flattening a list when iterating very nested json info

# %%
# To request data, need to provide NEON's URL
SERVER = 'http://data.neonscience.org/api/v0/'

# %% [markdown]
# Some of the important endpoints for NEON are:
# * _sites/_
# * _products/_
# * _data/_

# %%
# Define sites of interest
SITECODE_LIST = ['TEAK', 'SOAP', 'SJER']

# Make requests, then turn request data into a Python JSON object so it's easier to interact with
site_json_list = [requests.get(SERVER+'sites/'+SITECODE).json() 
                          for SITECODE in SITECODE_LIST]

# %%
# Display json info TEAK site
TEAK_json = site_json_list[0]
## TEAK_json ## super long output -- uncomment if you want to see

# %% [markdown]
# That was a huge dict...let's explore smaller parts and try to avoid listing the many dates

# %%
print(TEAK_json.keys(),'\n') # original dict only has 1 key -- 'data'

# look at info inside of 'data' key
NEON_dataDict_info = [str(key)+':\t'+str(type(TEAK_json['data'][key])) 
                          for key in TEAK_json['data'].keys()] 
print('\n'.join(NEON_dataDict_info), '\n')


# data products looked most interesting because I want to use that list to query products of interest
print('Exploring dataProducts')
dataProduct_Info = [str(type(product)) 
                        for product in TEAK_json['data']['dataProducts']] 
print('dataProducts contains a bunch of dicts...')
print(', '.join(dataProduct_Info), '\n')


print('What is in each of those dicts? They all have the same structure.')
dataProducts_ListOfDicts = TEAK_json['data']['dataProducts']
NEON_dataProducts_info = [str(subDict.keys())
                              for subDict in dataProducts_ListOfDicts] 
print('\n'.join(NEON_dataProducts_info), '\n')


print('What are the data product codes and titles?')
NEON_dataProductCodes_info = [str(productDict['dataProductCode'])+'\t'+str(productDict['dataProductTitle'])
                                  for productDict in dataProducts_ListOfDicts] 
print('\n'.join(NEON_dataProductCodes_info), '\n')
# Out:
# dict_keys(['data'])
#
# siteCode:	<class 'str'>
# siteName:	<class 'str'>
# siteDescription:	<class 'str'>
# siteType:	<class 'str'>
# siteLatitude:	<class 'float'>
# siteLongitude:	<class 'float'>
# stateCode:	<class 'str'>
# stateName:	<class 'str'>
# domainCode:	<class 'str'>
# domainName:	<class 'str'>
# deimsId:	<class 'str'>
# releases:	<class 'list'>
# dataProducts:	<class 'list'>
#
# Exploring dataProducts
# dataProducts contains a bunch of dicts...
# <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>, <class 'dict'>
#
# What is in each of those dicts? They all have the same structure.
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
# dict_keys(['dataProductCode', 'dataProductTitle', 'availableMonths', 'availableDataUrls', 'availableReleases'])
#
# What are the data product codes and titles?
# DP1.00001.001	2D wind speed and direction
# DP1.00002.001	Single aspirated air temperature
# DP1.00003.001	Triple aspirated air temperature
# DP1.00004.001	Barometric pressure
# DP1.00005.001	IR biological temperature
# DP1.00006.001	Precipitation
# DP1.00014.001	Shortwave radiation (direct and diffuse pyranometer)
# DP1.00023.001	Shortwave and longwave radiation (net radiometer)
# DP1.00024.001	Photosynthetically active radiation (PAR)
# DP1.00033.001	Phenology images
# DP1.00040.001	Soil heat flux plate
# DP1.00041.001	Soil temperature
# DP1.00042.001	Snow depth and understory phenology images
# DP1.00066.001	Photosynthetically active radiation (quantum line)
# DP1.00094.001	Soil water content and water salinity
# DP1.00095.001	Soil CO2 concentration
# DP1.00096.001	Soil physical and chemical properties, Megapit
# DP1.00098.001	Relative humidity
# DP1.10003.001	Breeding landbird point counts
# DP1.10010.001	Coarse downed wood log survey
# DP1.10017.001	Digital hemispheric photos of plot vegetation
# DP1.10020.001	Ground beetle sequences DNA barcode
# DP1.10022.001	Ground beetles sampled from pitfall traps
# DP1.10023.001	Herbaceous clip harvest
# DP1.10026.001	Plant foliar traits
# DP1.10033.001	Litterfall and fine woody debris production and chemistry
# DP1.10038.001	Mosquito sequences DNA barcode
# DP1.10041.001	Mosquito pathogen status
# DP1.10043.001	Mosquitoes sampled from CO2 traps
# DP1.10055.001	Plant phenology observations
# DP1.10058.001	Plant presence and percent cover
# DP1.10064.001	Rodent pathogen status, hantavirus
# DP1.10064.002	Rodent pathogen status, tick-borne
# DP1.10066.001	Root biomass and chemistry, Megapit
# DP1.10067.001	Root biomass and chemistry, periodic
# DP1.10072.001	Small mammal box trapping
# DP1.10076.001	Small mammal sequences DNA barcode
# DP1.10086.001	Soil physical and chemical properties, periodic
# DP1.10093.001	Ticks sampled using drag cloths
# DP1.10098.001	Vegetation structure
# DP1.10104.001	Soil microbe biomass
# DP1.10111.001	Site management and event reporting
# DP1.30001.001	LiDAR slant range waveform
# DP1.30003.001	Discrete return LiDAR point cloud
# DP1.30006.001	Spectrometer orthorectified surface directional reflectance - flightline
# DP1.30008.001	Spectrometer orthrorectified at-sensor radiance - flightline
# DP1.30010.001	High-resolution orthorectified camera imagery
# DP2.30011.001	Albedo - spectrometer - flightline
# DP2.30012.001	LAI - spectrometer - flightline
# DP2.30014.001	fPAR - spectrometer - flightline
# DP2.30019.001	Canopy water indices - flightline
# DP2.30026.001	Vegetation indices - spectrometer - flightline
# DP3.30006.001	Spectrometer orthorectified surface directional reflectance - mosaic
# DP3.30010.001	High-resolution orthorectified camera imagery mosaic
# DP3.30011.001	Albedo - spectrometer - mosaic
# DP3.30012.001	LAI - spectrometer - mosaic
# DP3.30014.001	fPAR - spectrometer - mosaic
# DP3.30015.001	Ecosystem structure
# DP3.30019.001	Canopy water indices - mosaic
# DP3.30024.001	Elevation - LiDAR
# DP3.30025.001	Slope and Aspect - LiDAR
# DP3.30026.001	Vegetation indices - spectrometer - mosaic
# DP4.00200.001	Bundled data products - eddy covariance

# %% [markdown]
# # Filtering URLs (for eventual download)
#
# Using this information about the data available for my 3 sites of interest, I want to download data that meet the following specifications for each site:
# * Data products:
#     * Vegetation structure (DP1.10098.001)
#     * Elevation - LiDAR (DP3.30024.001)
#     * Spectrometer orthorectified surface directional reflectance - mosaic (DP3.30006.001)
# * Most recent dataset

# %%
# Specifications
SERVER = 'http://data.neonscience.org/api/v0/'
SITES_LIST = ['TEAK', 'SOAP', 'SJER']
DATAPRODUCTS_DICT = {'Vegetation structure': 'DP1.10098.001', 
                     'Elevation - LiDAR': 'DP3.30024.001', 
                     'Spectrometer orthorectified surface directional reflectance - mosaic': 'DP3.30006.001'}

## Get a list of URLs for data to download ##

# get json info for my sites of interest
site_json_list = [requests.get(SERVER+'sites/'+site).json() 
                          for site in SITES_LIST]

# for each site, extract only the relevant dataproducts
dataprod_codes_list = list(DATAPRODUCTS_DICT.values())

def getProductsAtSite(site_json, dataprod_codes_list):
    return [site_dataProd_dict
            for site_dataProd_dict in site_json['data']['dataProducts']
            if site_dataProd_dict['dataProductCode'] in dataprod_codes_list
           ]

site_dataprod_dict = {site_json['data']['siteCode']:
                      getProductsAtSite(site_json, dataprod_codes_list)
                      for site_json in site_json_list}

## get the URL and only relevant metadata for only the most recent available datasets
# for each site, create a named tuple of tuples of the format below
productTupleNames = namedtuple('PRODUCT_METADATA', ['SITE','PRODUCT_TITLE', 'PRODUCT_CODE', 'DATE', 'URL'])

# for all products at all sites, get the metadata needed for our named productTuple
productTupleMetadata = list(chain(*[
    [(site,
      productD['dataProductTitle'],
      productD['dataProductCode'],
      productD['availableMonths'][-1],
      productD['availableDataUrls'][-1]
     )
     for productD in site_dataprod_dict[site]
    ]
    for site in site_dataprod_dict.keys()
]))

# the final named tuple with only our sites, products, and dates of interest
productTupleL=[productTupleNames(*productInfo)
               for productInfo in productTupleMetadata]

print(productTupleL)
# Out:
# [PRODUCT_METADATA(SITE='TEAK', PRODUCT_TITLE='Vegetation structure', PRODUCT_CODE='DP1.10098.001', DATE='2021-12', URL='https://data.neonscience.org/api/v0/data/DP1.10098.001/TEAK/2021-12'), PRODUCT_METADATA(SITE='TEAK', PRODUCT_TITLE='Spectrometer orthorectified surface directional reflectance - mosaic', PRODUCT_CODE='DP3.30006.001', DATE='2021-07', URL='https://data.neonscience.org/api/v0/data/DP3.30006.001/TEAK/2021-07'), PRODUCT_METADATA(SITE='TEAK', PRODUCT_TITLE='Elevation - LiDAR', PRODUCT_CODE='DP3.30024.001', DATE='2021-07', URL='https://data.neonscience.org/api/v0/data/DP3.30024.001/TEAK/2021-07'), PRODUCT_METADATA(SITE='SOAP', PRODUCT_TITLE='Vegetation structure', PRODUCT_CODE='DP1.10098.001', DATE='2022-01', URL='https://data.neonscience.org/api/v0/data/DP1.10098.001/SOAP/2022-01'), PRODUCT_METADATA(SITE='SOAP', PRODUCT_TITLE='Spectrometer orthorectified surface directional reflectance - mosaic', PRODUCT_CODE='DP3.30006.001', DATE='2021-07', URL='https://data.neonscience.org/api/v0/data/DP3.30006.001/SOAP/2021-07'), PRODUCT_METADATA(SITE='SOAP', PRODUCT_TITLE='Elevation - LiDAR', PRODUCT_CODE='DP3.30024.001', DATE='2021-07', URL='https://data.neonscience.org/api/v0/data/DP3.30024.001/SOAP/2021-07'), PRODUCT_METADATA(SITE='SJER', PRODUCT_TITLE='Vegetation structure', PRODUCT_CODE='DP1.10098.001', DATE='2022-02', URL='https://data.neonscience.org/api/v0/data/DP1.10098.001/SJER/2022-02'), PRODUCT_METADATA(SITE='SJER', PRODUCT_TITLE='Spectrometer orthorectified surface directional reflectance - mosaic', PRODUCT_CODE='DP3.30006.001', DATE='2021-03', URL='https://data.neonscience.org/api/v0/data/DP3.30006.001/SJER/2021-03'), PRODUCT_METADATA(SITE='SJER', PRODUCT_TITLE='Elevation - LiDAR', PRODUCT_CODE='DP3.30024.001', DATE='2021-03', URL='https://data.neonscience.org/api/v0/data/DP3.30024.001/SJER/2021-03')]

# %%
# exploring the files to download from each URL
for product_metadata in productTupleL:
    # make request with saved url
    data_request = requests.get(product_metadata.URL)
    data_json = data_request.json()
    
    # print info on the files we can access for this particular site and product
    print(product_metadata.SITE, '\t|', product_metadata.PRODUCT_TITLE)
    print('\n'.join(set([' '.join(fileD['name'].replace('.','_').split('_')[6:]) # the first 6 info slots are redundant 
                     for fileD in data_json['data']['files']]) # for clarity, I used set to remove duplicate printouts -- but there are LOTS of h5 files
                   ),
         '\n\n')
# Out:
# TEAK 	| Vegetation structure
# vst perplotperyear 2021-12 basic 20220711T220416Z csv
# readme 20220711T220416Z txt
# categoricalCodes 20220711T220416Z csv
# variables 20220711T220416Z csv
# validation 20220711T220416Z csv
# vst mappingandtagging basic 20220711T220416Z csv
# EML 20211207-20211208 20220711T220416Z xml
# vst apparentindividual 2021-12 basic 20220711T220416Z csv
#
#
# TEAK 	| Spectrometer orthorectified surface directional reflectance - mosaic
# readme 20211007T212640Z txt
# pdf
# reflectance h5
#
#
# TEAK 	| Elevation - LiDAR
#
# classified point cloud shp
# readme 20211007T212640Z txt
# classified point cloud dbf
# classified point cloud kml
# DTM tif
# classified point cloud prj
# processing pdf
# classified point cloud shx
# DSM tif
#
#
# SOAP 	| Vegetation structure
# variables 20220801T222504Z csv
# EML 20220117-20220117 20220801T222504Z xml
# vst perplotperyear 2022-01 basic 20220801T222504Z csv
# categoricalCodes 20220801T222504Z csv
# validation 20220801T222504Z csv
# vst mappingandtagging basic 20220801T222504Z csv
# readme 20220801T222504Z txt
#
#
# SOAP 	| Spectrometer orthorectified surface directional reflectance - mosaic
# readme 20220131T195357Z txt
# pdf
# reflectance h5
#
#
# SOAP 	| Elevation - LiDAR
#
# classified point cloud shp
# readme 20211007T212640Z txt
# classified point cloud kml
# classified point cloud dbf
# DTM tif
# classified point cloud prj
# processing pdf
# classified point cloud shx
# DSM tif
#
#
# SJER 	| Vegetation structure
# validation 20220829T155208Z csv
# vst apparentindividual 2022-02 basic 20220829T155208Z csv
# variables 20220829T155208Z csv
# EML 20220201-20220202 20220829T155208Z xml
# vst perplotperyear 2022-02 basic 20220829T155208Z csv
# categoricalCodes 20220829T155208Z csv
# readme 20220829T155208Z txt
# vst mappingandtagging basic 20220829T155208Z csv
#
#
# SJER 	| Spectrometer orthorectified surface directional reflectance - mosaic
#
# spectrometer processing pdf
# readme 20220120T173946Z txt
# pdf
# reflectance h5
#
#
# SJER 	| Elevation - LiDAR
#
# readme 20220302T205717Z txt
# classified point cloud shp
# classified point cloud dbf
# classified point cloud kml
# DTM tif
# classified point cloud prj
# processing pdf
# classified point cloud shx
# DSM tif

# %% [markdown]
# # Detour: Downloading only 1 h5 file for initial exploration
#
# In my original workflow planning, I didn't really put together that there would be SO MANY files associated with each plot's DSM, DTM, and reflectance data, because the data are tiled. So, I'm taking a quick detour to explore reflectance data from a single tile and then I'll learn to put the tiles back into the original mosaic so I can proceed with my workflow.

# %%
teak_reflectance_metadata = list(filter(lambda x: x.PRODUCT_TITLE == 'Spectrometer orthorectified surface directional reflectance - mosaic' 
                                   and x.SITE == 'TEAK', 
                                   productTupleL)).pop()

# make request with saved url
data_request = requests.get(teak_reflectance_metadata.URL)
data_json = data_request.json()
all_teak_h5_urls = [fileD['url'] for fileD in data_json['data']['files'] 
                                if fileD['name'].endswith('.h5')]
all_teak_h5_urls
# Out:
# ['https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4091000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4103000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4104000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4104000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4104000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4095000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4099000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4100000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4105000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4099000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4099000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4092000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4107000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_312000_4092000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_325000_4108000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4109000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_325000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4099000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4092000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4098000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4106000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4100000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4091000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4107000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4102000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4108000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4101000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4093000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4101000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4108000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4104000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4092000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4091000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4094000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4092000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4093000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4090000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4107000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4098000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4100000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4093000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4104000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4105000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4099000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4094000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4102000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4103000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4094000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4100000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4094000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4103000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4101000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4099000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4092000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4108000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4090000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4103000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4102000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4102000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4095000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4106000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_325000_4102000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4100000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4098000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4106000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4105000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4090000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4104000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4108000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4105000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4102000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4105000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4108000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4101000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4108000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4092000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4107000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4099000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4107000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4093000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4102000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4090000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4108000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4099000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4101000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4093000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4102000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_325000_4100000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4092000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4098000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4098000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4099000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4100000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_326000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4091000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_325000_4098000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4100000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4100000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4090000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4106000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4093000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4100000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4095000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4104000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4090000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4106000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4102000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4105000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4094000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4095000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4100000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4095000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4098000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4106000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4103000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4105000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4090000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_312000_4094000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4105000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4091000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4090000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4107000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4091000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4105000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4091000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4091000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_312000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4107000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_312000_4091000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4107000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4093000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4095000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_325000_4101000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4102000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4093000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4098000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4103000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4094000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4093000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4095000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4106000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4092000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4093000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4109000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4101000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4095000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4098000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4093000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4107000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4103000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4103000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4104000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4107000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4098000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4092000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4104000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4091000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4105000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4098000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4104000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_312000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4094000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4090000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4101000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4108000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4106000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4108000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4106000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_326000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4094000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4104000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4089000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4095000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4091000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4099000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4108000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4091000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4103000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_325000_4105000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4090000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4108000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4100000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4108000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4098000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4095000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4107000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4098000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4105000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4106000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_325000_4104000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4093000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4103000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4101000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4109000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4099000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_325000_4097000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_315000_4092000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4101000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4095000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4107000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4094000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_317000_4090000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4101000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4100000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4094000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4101000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_325000_4103000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_322000_4092000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4092000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4106000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_312000_4093000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_316000_4090000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4103000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4102000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4094000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_324000_4095000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4102000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_314000_4094000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_325000_4099000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_318000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_325000_4107000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_312000_4090000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4101000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_325000_4106000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_321000_4103000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4102000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_320000_4099000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_323000_4091000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4106000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4096000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_313000_4105000_reflectance.h5',
#  'https://storage.googleapis.com/neon-aop-products/2021/FullSite/D17/2021_TEAK_5/L3/Spectrometer/Reflectance/NEON_D17_TEAK_DP3_319000_4104000_reflectance.h5']

# %% [markdown]
# ##### TODO
# Next steps will be to explore the neonUtilities package for automatically downloading a set of h5 files. Once I have that figured out, I'll created a new regular .py file that can take in sites and a path to save to for automatically downloading/organizing a set of h5 files. At that point, I will experiment with the hoffman2 cluster, too because the downloading of files has been pretty slow.

# %%
h5_path = '/Users/cd/Documents/Graduate_School/SURP/SURP_practice/teak_reflectance/NEON_D17_TEAK_DP3_319000_4091000_reflectance.h5'
f = h5py.File(h5_path, 'r')

# list_dataset function from NEON tutorial documentation
#list_dataset lists the names of datasets in an hdf5 file
def list_dataset(name,node):
    if isinstance(node, h5py.Dataset):
        print(name)

f.visititems(list_dataset) # recursively explores entire hd5f file structure
# Out:
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Aerosol_Optical_Depth
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Aspect
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Cast_Shadow
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Dark_Dense_Vegetation_Classification
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Data_Selection_Index
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Haze_Cloud_Water_Map
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Illumination_Factor
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Path_Length
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Sky_View_Factor
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Slope
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Smooth_Surface_Elevation
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Visibility_Index_Map
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Water_Vapor_Column
# TEAK/Reflectance/Metadata/Ancillary_Imagery/Weather_Quality_Indicator
# TEAK/Reflectance/Metadata/Coordinate_System/Coordinate_System_String
# TEAK/Reflectance/Metadata/Coordinate_System/EPSG Code
# TEAK/Reflectance/Metadata/Coordinate_System/Map_Info
# TEAK/Reflectance/Metadata/Coordinate_System/Proj4
# TEAK/Reflectance/Metadata/Logs/181459/ATCOR_Input_file
# TEAK/Reflectance/Metadata/Logs/181459/ATCOR_Processing_Log
# TEAK/Reflectance/Metadata/Logs/181459/Shadow_Processing_Log
# TEAK/Reflectance/Metadata/Logs/181459/Skyview_Processing_Log
# TEAK/Reflectance/Metadata/Logs/181459/Solar_Azimuth_Angle
# TEAK/Reflectance/Metadata/Logs/181459/Solar_Zenith_Angle
# TEAK/Reflectance/Metadata/Logs/182227/ATCOR_Input_file
# TEAK/Reflectance/Metadata/Logs/182227/ATCOR_Processing_Log
# TEAK/Reflectance/Metadata/Logs/182227/Shadow_Processing_Log
# TEAK/Reflectance/Metadata/Logs/182227/Skyview_Processing_Log
# TEAK/Reflectance/Metadata/Logs/182227/Solar_Azimuth_Angle
# TEAK/Reflectance/Metadata/Logs/182227/Solar_Zenith_Angle
# TEAK/Reflectance/Metadata/Logs/191011/ATCOR_Input_file
# TEAK/Reflectance/Metadata/Logs/191011/ATCOR_Processing_Log
# TEAK/Reflectance/Metadata/Logs/191011/Shadow_Processing_Log
# TEAK/Reflectance/Metadata/Logs/191011/Skyview_Processing_Log
# TEAK/Reflectance/Metadata/Logs/191011/Solar_Azimuth_Angle
# TEAK/Reflectance/Metadata/Logs/191011/Solar_Zenith_Angle
# TEAK/Reflectance/Metadata/Logs/191845/ATCOR_Input_file
# TEAK/Reflectance/Metadata/Logs/191845/ATCOR_Processing_Log
# TEAK/Reflectance/Metadata/Logs/191845/Shadow_Processing_Log
# TEAK/Reflectance/Metadata/Logs/191845/Skyview_Processing_Log
# TEAK/Reflectance/Metadata/Logs/191845/Solar_Azimuth_Angle
# TEAK/Reflectance/Metadata/Logs/191845/Solar_Zenith_Angle
# TEAK/Reflectance/Metadata/Logs/192549/ATCOR_Input_file
# TEAK/Reflectance/Metadata/Logs/192549/ATCOR_Processing_Log
# TEAK/Reflectance/Metadata/Logs/192549/Shadow_Processing_Log
# TEAK/Reflectance/Metadata/Logs/192549/Skyview_Processing_Log
# TEAK/Reflectance/Metadata/Logs/192549/Solar_Azimuth_Angle
# TEAK/Reflectance/Metadata/Logs/192549/Solar_Zenith_Angle
# TEAK/Reflectance/Metadata/Logs/214819/ATCOR_Input_file
# TEAK/Reflectance/Metadata/Logs/214819/ATCOR_Processing_Log
# TEAK/Reflectance/Metadata/Logs/214819/Shadow_Processing_Log
# TEAK/Reflectance/Metadata/Logs/214819/Skyview_Processing_Log
# TEAK/Reflectance/Metadata/Logs/214819/Solar_Azimuth_Angle
# TEAK/Reflectance/Metadata/Logs/214819/Solar_Zenith_Angle
# TEAK/Reflectance/Metadata/Spectral_Data/FWHM
# TEAK/Reflectance/Metadata/Spectral_Data/Wavelength
# TEAK/Reflectance/Metadata/to-sensor_azimuth_angle
# TEAK/Reflectance/Metadata/to-sensor_zenith_angle
# TEAK/Reflectance/Reflectance_Data

# %%
## Exploring the h5py type
print('Type:', type(f))
print('Methods:\n', '\n'.join([str(method) for method in dir(f)]))
print('Attributes:', vars(f))
print(f.attrs, list(f.attrs))
# Out:
# Type: <class 'h5py._hl.files.File'>
# Methods:
#  _MutableMapping__marker
# __abstractmethods__
# __bool__
# __class__
# __class_getitem__
# __contains__
# __delattr__
# __delitem__
# __dict__
# __dir__
# __doc__
# __enter__
# __eq__
# __exit__
# __format__
# __ge__
# __getattribute__
# __getitem__
# __getnewargs__
# __getstate__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __iter__
# __le__
# __len__
# __lt__
# __module__
# __ne__
# __new__
# __nonzero__
# __reduce__
# __reduce_ex__
# __repr__
# __reversed__
# __setattr__
# __setitem__
# __sizeof__
# __slots__
# __str__
# __subclasshook__
# __weakref__
# _abc_impl
# _d
# _e
# _gcpl_crt_order
# _id
# _ipython_key_completions_
# _lapl
# _lcpl
# _libver
# attrs
# build_virtual_dataset
# clear
# close
# copy
# create_dataset
# create_dataset_like
# create_group
# create_virtual_dataset
# driver
# file
# filename
# flush
# get
# id
# items
# keys
# libver
# mode
# move
# name
# parent
# pop
# popitem
# ref
# regionref
# require_dataset
# require_group
# setdefault
# swmr_mode
# update
# userblock_size
# values
# visit
# visititems
# Attributes: {'_libver': (None, 'latest'), '_id': <h5py.h5f.FileID object at 0x141f2bbd0>}
# <Attributes of HDF5 object at 5400545536> []

# %%
teak_refl = f['TEAK']['Reflectance']

## How to index into the reflectance data 
print(teak_refl.attrs.keys()) # at a given level, can see the keys/values for the attributes
print('TEAK Description output:', teak_refl.attrs['Description'])

print(teak_refl, '\n', list(teak_refl), '\n\n') # can also see both members of teak_refl by listing

## How to index into the Reflectance data
print('INDEXING INTO THE REFLECTANCE DATA')
teak_reflArray = teak_refl['Reflectance_Data'] # exploring the reflectance_data member
print('Teak reflectance array:\n', teak_reflArray) # the shape is (y, x, bands)
print(teak_reflArray.attrs.keys())
print('Teak reflectance spatial resolution:', teak_reflArray.attrs['Spatial_Resolution_X_Y'],'\n\n')


## How to index into the map info (an h5 Dataset type)
print('INDEXING INTO THE MAP INFO METADATA')
teak_mapInfo = teak_refl['Metadata']['Coordinate_System']['Map_Info'] # can use the printed file structure from visititems to access info of interest
print('TEAK Map attributes --', list(teak_mapInfo.attrs.keys()))
print('TEAK Map info --', teak_mapInfo.attrs['Description'])
print(list(filter(lambda x: not x.startswith('_'), dir(teak_mapInfo)))) # what methods exist for this type?
print(list(vars(teak_mapInfo).keys()), '\n\n') # what attributes exist for this type?

## after looking into the h5py docs, I saw that an alternative to slicing with indices (eg mapInfo[0]) is to get all info using [()]
str(teak_mapInfo[()]) # can't use teak_mapInfo.value as suggested in NEON tutorial -- error

# print what the mapInfo data correspond to (based on Description)
descriptions = teak_mapInfo.attrs['Description'].split('\n')[1:]
data = str(teak_mapInfo[()]).split(', ')
print('\n'.join(['{:15}'.format(dat.strip())+desc.strip() for dat, desc in zip(data, descriptions)]))
# Out:
# <KeysViewHDF5 ['Band_Window_1_Nanometers', 'Band_Window_2_Nanometers', 'Description', 'PayloadID', 'Sensor']>
# TEAK Description output: Calibrated, processed, atmospherically corrected and geometrically located reflectance data and associated ancillary imagery derived from NEON Airborne Observatory Platform (AOP) Imaging Spectrometer
# <HDF5 group "/TEAK/Reflectance" (2 members)>
#  ['Metadata', 'Reflectance_Data']
#
#
# INDEXING INTO THE REFLECTANCE DATA
# Teak reflectance array:
#  <HDF5 dataset "Reflectance_Data": shape (1000, 1000, 426), type "<i2">
# <KeysViewHDF5 ['Cloud_conditions', 'Cloud_type', 'Data_Ignore_Value', 'Description', 'Dimension_Labels', 'Dimensions', 'Interleave', 'Scale_Factor', 'Spatial_Extent_meters', 'Spatial_Resolution_X_Y', 'Units', 'Units_Valid_range']>
# Teak reflectance spatial resolution: [1. 1.]
#
#
# INDEXING INTO THE MAP INFO METADATA
# TEAK Map attributes -- ['Description']
# TEAK Map info -- List of geographic information in the following order:
# - Projection name
# - Reference (tie point) pixel x location (in file coordinates)
# - Reference (tie point) pixel y location (in file coordinates)
# - Pixel easting
# - Pixel northing
# - x pixel size
# - y pixel size
# - Projection zone (UTM only)
# - North or South (UTM only)
# - Datum
# - Units
# - Rotation Angle
# ['asstr', 'astype', 'attrs', 'chunks', 'compression', 'compression_opts', 'dims', 'dtype', 'external', 'fields', 'file', 'fillvalue', 'fletcher32', 'flush', 'id', 'is_virtual', 'iter_chunks', 'len', 'make_scale', 'maxshape', 'name', 'nbytes', 'ndim', 'parent', 'read_direct', 'ref', 'refresh', 'regionref', 'resize', 'scaleoffset', 'shape', 'shuffle', 'size', 'virtual_sources', 'write_direct']
# ['_id', '_dcpl', '_dxpl', '_filters', '_readonly', '_cache_props', '_local']
#
#
# b'UTM          - Projection name
# 1.000          - Reference (tie point) pixel x location (in file coordinates)
# 1.000          - Reference (tie point) pixel y location (in file coordinates)
# 319000.00      - Pixel easting
# 4092000.0      - Pixel northing
# 1.0000000      - x pixel size
# 1.0000000      - y pixel size
# 11             - Projection zone (UTM only)
# North          - North or South (UTM only)
# WGS-84         - Datum
# units=Meters   - Units
# 0'             - Rotation Angle

# %% [markdown]
# ### Visualizing h5 bands
# Now that I've explored the structure of h5 files a bit, I understand that the original h5 file (h for hierarchical) contains many sets of nested datasets, each of which can be indexed slightly differently. The biggest takeaway is to check the file type, print the .attrs.keys() of a variable, and that [()] can sometimes be used when other indexing attempts fail.
#
# Next, I'll be tyring to visualize 1 to 3 bands of the downloaded data. According to [this NEON tutorial](https://www.neonscience.org/resources/learning-hub/tutorials/neon-hsi-aop-functions-tiles-py), the bands corresponding to RGB are:
# * Blue: 474nm, band 19
# * Green: 549nm, band 34
# * Red: 669nm, band 58
